# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 31.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=8565605577349d79179af218207e2276dbbefdfa3291f4cc04ce3d82d1e40956
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
from skfuzzy.control.rule import Rule
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
from mpl_toolkits.mplot3d import Axes3D as ax
import math

universe = np.linspace(-math.pi/2, math.pi/2, 101)
universe = np.linspace(0,100,101)

alpha = ctrl.Antecedent(universe,'alpha')
dedt = ctrl.Antecedent(universe,'dedt')
force = ctrl.Antecedent(universe,'force')

name_1 = ['LN','N','Z','P','LP']
name_2 = ['-2','-1','0','1','2']

alpha.automf(names = name_1)
dedt.automf(names = name_1)
force.automf(names = name_2)

rule_2_ = ctrl.Rule(antecedent= ((alpha[''] & dedt[''])), consequent = force['-2'], label = 'rule_2_')
rule_1_ = ctrl.Rule(antecedent= ((alpha[''] & dedt[''])), consequent = force['-1'], label = 'rule_1_')
rule_0 = ctrl.Rule(antecedent= ((alpha[''] & dedt[''])), consequent = force['0'], label = 'rule_0')
rule_1 = ctrl.Rule(antecedent= ((alpha[''] & dedt[''])), consequent = force['1'], label = 'rule_1')
rule_2 = ctrl.Rule(antecedent= ((alpha[''] & dedt[''])), consequent = force['2'], label = 'rule_2')

#rule_2- = ctrl.Rule(antecedent= ((alpha['LN'] & dedt['LN']) | (alpha['N'] & dedt['LN']) | (anpha['LN'] & dedt['N'])), consequent = force['-2'], label = 'rule_2-')rule_1- = ctrl.Rule(antecedent= ((alpha['Z'] & dedt['LN']) | (alpha['P'] & dedt['LN']) | (anpha['N'] & dedt['N']) | (anpha['Z'] & dedt['N']) | (anpha['LN'] & dedt['Z']) | (anpha['N'] & dedt['Z']) | (anpha['LN'] & dedt['P'])), consequent = force['-1'], label = 'rule_1-')
#rule_2 = ctrl.Rule(antecedent= ((alpha['LN'] & dedt['LN']) | (alpha['N'] & dedt['LN']) | (anpha['LN'] & dedt['N'])), consequent = force['-2'], label = 'rule_2-')
#rule_2 = ctrl.Rule(antecedent= ((alpha['LN'] & dedt['LN']) | (alpha['N'] & dedt['LN']) | (anpha['LN'] & dedt['N'])), consequent = force['-2'], label = 'rule_2-')
#rule_2 = ctrl.Rule(antecedent= ((alpha['LN'] & dedt['LN']) | (alpha['N'] & dedt['LN']) | (anpha['LN'] & dedt['N'])), consequent = force['-2'], label = 'rule_2-')
